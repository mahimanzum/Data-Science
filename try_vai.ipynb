# %%
import glob

readpath0 = 'C:/Users/HP/Desktop/Data Science/data/A/*jpg'
readpath1 = 'C:/Users/HP/Desktop/Data Science/data/B/*jpg'
labels = 'C:/Users/HP/Desktop/Data Science/data/labels.csv'
objectClass0 = 'A'
objectClass1 = 'B'

images = glob.glob(readpath0)
labelfile = open(labels,'w')

for image in images:
    labelfile.write(image+','+objectClass0+'\n')
images = glob.glob(readpath1)
for image in images:
    labelfile.write(image+','+objectClass1+'\n')
labelfile.close()

# %%
import random
labels = 'C:/Users/HP/Desktop/Data Science/data/labels.csv'
shuffled_labels = 'C:/Users/HP/Desktop/Data Science/data/shuffled_labels.csv'

labelfile = open(labels, "r")
lines = labelfile.readlines()
labelfile.close()
random.shuffle(lines)

shufflefile = open(shuffled_labels, "w")
shufflefile.writelines(lines)
shufflefile.close()

# %%
import cv2
import pandas
import numpy as np
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils

labels = 'C:/Users/HP/Desktop/Data Science/data/shuffled_labels.csv'
npzfile = 'C:/Users/HP/Desktop/Data Science/data/labels.npz'

df = pandas.read_csv(labels)

rows = df.iterrows()

X_temp = []
Y_temp = []

for row in rows:
    image = row[1][0]
    img = cv2.imread(image)
    img = cv2.resize(img,(32,32))
    imageClass = row[1][1]
    print(type(img[0][0][0]))
    X_temp.append(img)
    Y_temp.append(imageClass)


encoder = LabelEncoder()
encoder.fit(Y_temp)
encoded_Y = encoder.transform(Y_temp)
Y = np_utils.to_categorical(encoded_Y)

np.savez(npzfile, X_train=X_temp,Y_train=Y)
# Out:
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>
# <class 'numpy.uint8'>

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers.convolutional import Convolution2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint
from keras import backend as K
K.set_image_data_format('channels_last')

seed = 7
np.random.seed(seed)
num_classes = 2


npzfile = 'H:/Workshop/Lecture Plan/Lecture 6/Labels/labels.npz'

dataset =  np.load(npzfile)
x_train = dataset['X_train']
y_train = dataset['Y_train']
print(type(x_train))
x_train = x_train/255
print(x_train.shape)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-173d3ddc2931> in <module>()
#      14 npzfile = 'H:/Workshop/Lecture Plan/Lecture 6/Labels/labels.npz'
#      15
# ---> 16 dataset =  np.load(npzfile)
#      17 x_train = dataset['X_train']
#      18 y_train = dataset['Y_train']
#
# ~\Anaconda3\envs\workshop\lib\site-packages\numpy\lib\npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     368     own_fid = False
#     369     if isinstance(file, basestring):
# --> 370         fid = open(file, "rb")
#     371         own_fid = True
#     372     elif is_pathlib_path(file):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'H:/Workshop/Lecture Plan/Lecture 6/Labels/labels.npz'

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers.convolutional import Convolution2D,MaxPooling2D
from keras.callbacks import ModelCheckpoint
from keras import backend as K
K.set_image_data_format('channels_last')

def CNN_model():
    # create model
    model = Sequential()
    model.add(Convolution2D(32, (5, 5), border_mode= 'valid' , input_shape=(32,32,3),activation= 'relu' ))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation= 'relu' ))
    model.add(Dense(num_classes, activation= 'softmax' ))
    # Compile model
    model.compile(loss= 'categorical_crossentropy' , optimizer= 'adam' , metrics=[ 'accuracy' ])
    return model

model = CNN_model()

model.summary()

check  = ModelCheckpoint('best.hdf5', monitor = 'val_categorical_accuracy' )
checkpoints = [check]

model.fit(x_train, y_train, validation_split = 0.2, epochs=20, batch_size=32,verbose=2, callbacks = checkpoints)
# Out:
# C:\Users\HP\Anaconda3\envs\workshop\lib\site-packages\ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), input_shape=(32, 32, 3..., activation="relu", padding="valid")`
#   if sys.path[0] == '':
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 28, 28, 32)        2432
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 32)        0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 6272)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               802944
# _________________________________________________________________
# dense_4 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 805,634
# Trainable params: 805,634
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-eccc86e4dc28> in <module>()
#      27 checkpoints = [check]
#      28
# ---> 29 model.fit(x_train, y_train, validation_split = 0.2, epochs=20, batch_size=32,verbose=2, callbacks = checkpoints)
#
# NameError: name 'x_train' is not defined

# %%
import cv2
import numpy as np
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers.convolutional import Convolution2D,MaxPooling2D
from keras import backend as K
K.set_image_data_format('channels_last')

# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
num_classes = 2

img = cv2.imread('testObject2.jpg')
imgRes = cv2.resize(img,(32,32))

X_temp = []
X_temp.append(imgRes)
X = np.asarray(X_temp)
X = X/255

def CNN_model():
    # create model
    model = Sequential()
    model.add(Convolution2D(32, 5, 5, border_mode= 'valid' , input_shape=(32,32,3),activation= 'relu' ))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.2))
    model.add(Flatten())
    model.add(Dense(128, activation= 'relu' ))
    model.add(Dense(num_classes, activation= 'softmax' ))
    # Compile model
    model.compile(loss= 'categorical_crossentropy' , optimizer= 'adam' , metrics=[ 'accuracy' ])
    return model

model = CNN_model()

model.load_weights('best.hdf5')

y = model.predict_classes(X)
classno = np.ndarray.tolist(y)

dict = {0: 'Burger', 1: 'Pizza'}
objectClass = dict[classno[0]]
print(objectClass)

font = cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img, objectClass,(50,50), font, 2, (200,255,0), 5, cv2.LINE_AA)
cv2.imshow('Prediction',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# C:\Users\HP\Anaconda3\envs\workshop\lib\site-packages\ipykernel_launcher.py:25: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (5, 5), input_shape=(32, 32, 3..., activation="relu", padding="valid")`
# 1/1 [==============================] - 0s 127ms/step
# Pizza
